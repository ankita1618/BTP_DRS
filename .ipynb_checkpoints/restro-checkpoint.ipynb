# %%
import pandas as pd
import math, re, urllib, requests

# %%
attr = pd.read_csv('Attractions.csv')
restro = pd.read_csv('Restaurant.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-19610311b576> in <module>
# ----> 1 attr = pd.read_csv('Attractions.csv')
#       2 restro = pd.read_csv('Restaurant.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
def get_loc(address, position, maps_key='AIzaSyCSnuuGE7ZcSHPJUUXU6p2SJiyehAfWTQ8'):
    maps_api_url = 'https://maps.googleapis.com/maps/api/geocode/json'
    request_url = maps_api_url + '?' + urllib.parse.urlencode({'address':address,'key':maps_key})
    response = requests.get(request_url)
    resp_json_payload = response.json()
    print(response.json())
    if(len(resp_json_payload['results'])==0):
        return 'NaN'
    out = resp_json_payload['results'][0]['geometry']['location']
    if position == 'latitude':
        return float(out['lat'])
    elif position == 'longitude':
        return float(out['lng'])

# %%
restro.columns
# Out:
# Index(['Name', 'Address ', 'Main Location', 'Description', 'Rating',
#        'Open time', 'Close time', 'Cost for two', 'Cuisines'],
#       dtype='object')

# %%
restro.head()
# Out:
#                   Name                                        Address   \
# 0        Sorriso Pizza  2nd Floor, Al Hayat Building, Main Bazaar, Leh
# 1  The Tibetan Kitchen  Old Fort Road, Near J&K Bank, Main Bazaar, Leh
# 2            U.S.Pizza      First Floor, AMI Complex, Main bazaar, Leh
# 3     Gesmo Restaurant    Shamsha Complex, Fort Road, Main Bazaar, Leh
# 4       Himalayan Cafe     2nd Floor, Samkar Complex, Main Bazaar, Leh
#
#   Main Location          Description Rating Open time Close time  \
# 0   Main Bazaar          Quick Bites    4.9     10:30      22:00
# 1   Main Bazaar        Casual Dining    3.5     12:00      23:00
# 2   Main Bazaar          Quick bites    3.6     11:00      23:00
# 3   Main Bazaar  Quick Bites, bakery    3.2     11:00      23:00
# 4   Main Bazaar                 cafe    3.9     11:00      23:00
#
#    Cost for two                             Cuisines
# 0           500                     Pizza, Fast Food
# ...

# %%
print(restro.shape)
# Out:
# (81, 9)

# %%
latitudes = []
for i in restro['Address ']:
#     print(get_loc(i, 'latitude'))
    a = get_loc(i, 'latitude')
    latitudes.append(a)
    print(len(latitudes))
# Out:
# {'results': [{'address_components': [{'long_name': '194101', 'short_name': '194101', 'types': ['postal_code']}, {'long_name': 'Leh', 'short_name': 'Leh', 'types': ['locality', 'political']}], 'formatted_address': '2nd floor al hayat building main bazar rd Leh leh Jammu and Kashmir, Leh, 194101', 'geometry': {'location': {'lat': 34.1623878, 'lng': 77.58541579999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 34.1637367802915, 'lng': 77.5867647802915}, 'southwest': {'lat': 34.1610388197085, 'lng': 77.58406681970848}}}, 'place_id': 'ChIJP4ryomrr_TgRnWkVAPJ1Ndk', 'plus_code': {'compound_code': '5H6P+X5 Leh, Jammu and Kashmir', 'global_code': '8J6V5H6P+X5'}, 'types': ['establishment', 'food', 'meal_delivery', 'meal_takeaway', 'point_of_interest', 'restaurant']}], 'status': 'OK'}
# 1
# ...

# %%
latitudes
# Out:
# [34.1623878,
#  34.163343,
#  34.164832,
#  34.163644,
#  34.164832,
#  34.163644,
#  34.163644,
#  34.163644,
#  34.163644,
#  34.1621111,
#  34.1637676,
#  34.163644,
#  34.1636247,
#  34.1490527,
#  34.164703,
#  34.1490527,
#  34.1560475,
#  34.1607986,
#  34.1607986,
#  34.163644,
#  34.1622108,
#  34.1621111,
#  'NaN',
#  39.7399,
#  12.324051,
#  34.1671462,
#  34.1668139,
#  34.164832,
#  34.163343,
#  'NaN',
#  34.152195,
#  34.163644,
#  'NaN',
#  34.163644,
#  53.86794339999999,
#  34.163644,
#  34.1560475,
#  34.1647171,
#  34.165196,
#  34.163644,
#  34.1658457,
#  34.1528868,
#  34.163644,
#  34.163691,
#  'NaN',
#  34.1662392,
#  34.1634117,
#  34.164703,
#  34.163644,
#  34.1648006,
#  34.1621111,
#  34.1621111,
#  34.1537938,
#  34.163644,
#  34.163644,
#  53.86794339999999,
#  34.163644,
#  34.1651268,
#  34.163644,
#  34.163644,
#  34.163644,
#  34.1607986,
#  34.163644,
#  34.163644,
#  34.163644,
#  34.1623345,
#  34.163644,
#  34.164832,
#  33.9136846,
# ...

# %%
longitudes = []
for i in restro['Address ']:
#     print(get_loc(i, 'latitude'))
    a = get_loc(i, 'longitude')
    longitudes.append(a)
    print(len(longitudes))
# Out:
# {'results': [{'address_components': [{'long_name': '194101', 'short_name': '194101', 'types': ['postal_code']}, {'long_name': 'Leh', 'short_name': 'Leh', 'types': ['locality', 'political']}], 'formatted_address': '2nd floor al hayat building main bazar rd Leh leh Jammu and Kashmir, Leh, 194101', 'geometry': {'location': {'lat': 34.1623878, 'lng': 77.58541579999999}, 'location_type': 'GEOMETRIC_CENTER', 'viewport': {'northeast': {'lat': 34.1637367802915, 'lng': 77.5867647802915}, 'southwest': {'lat': 34.1610388197085, 'lng': 77.58406681970848}}}, 'place_id': 'ChIJP4ryomrr_TgRnWkVAPJ1Ndk', 'plus_code': {'compound_code': '5H6P+X5 Leh, Jammu and Kashmir', 'global_code': '8J6V5H6P+X5'}, 'types': ['establishment', 'food', 'meal_delivery', 'meal_takeaway', 'point_of_interest', 'restaurant']}], 'status': 'OK'}
# 1
# ...

# %%
longitudes
# Out:
# [77.58541579999999,
#  77.5840607,
#  77.584444,
#  77.58550650000001,
#  77.584444,
#  77.58550650000001,
#  77.58550650000001,
#  77.58550650000001,
#  77.58550650000001,
#  77.5839257,
#  77.5826014,
#  77.58550650000001,
#  77.58409200000001,
#  77.5744346,
#  77.585129,
#  77.5744346,
#  77.5726068,
#  77.57680409999999,
#  77.57680409999999,
#  77.58550650000001,
#  77.58552209999999,
#  77.5839257,
#  'NaN',
#  -104.8557389,
#  76.6279102,
#  77.5825016,
#  77.5840832,
#  77.584444,
#  77.5840607,
#  'NaN',
#  77.57455499999999,
#  77.58550650000001,
#  'NaN',
#  77.58550650000001,
#  -1.6615306,
#  77.58550650000001,
#  77.5726068,
#  77.5850385,
#  77.5841939,
#  77.58550650000001,
#  77.5872289,
#  77.5755143,
#  77.58550650000001,
#  77.585448,
#  'NaN',
#  77.5836082,
#  77.5852668,
#  77.585129,
#  77.58550650000001,
#  77.5842164,
#  77.5839257,
#  77.5839257,
#  77.58021029999999,
#  77.58550650000001,
#  77.58550650000001,
#  -1.6615306,
#  77.58550650000001,
# ...

# %%
restro['latitude'] = latitudes
restro['longitude'] = longitudes

# %%
restro.head()
# Out:
#                   Name                                        Address   \
# 0        Sorriso Pizza  2nd Floor, Al Hayat Building, Main Bazaar, Leh
# 1  The Tibetan Kitchen  Old Fort Road, Near J&K Bank, Main Bazaar, Leh
# 2            U.S.Pizza      First Floor, AMI Complex, Main bazaar, Leh
# 3     Gesmo Restaurant    Shamsha Complex, Fort Road, Main Bazaar, Leh
# 4       Himalayan Cafe     2nd Floor, Samkar Complex, Main Bazaar, Leh
#
#   Main Location          Description Rating Open time Close time  \
# 0   Main Bazaar          Quick Bites    4.9     10:30      22:00
# 1   Main Bazaar        Casual Dining    3.5     12:00      23:00
# 2   Main Bazaar          Quick bites    3.6     11:00      23:00
# 3   Main Bazaar  Quick Bites, bakery    3.2     11:00      23:00
# 4   Main Bazaar                 cafe    3.9     11:00      23:00
#
#    Cost for two                             Cuisines latitude longitude
# 0           500                     Pizza, Fast Food  34.1624   77.5854
# ...

# %%
hotel = pd.read_csv('Hotels.csv')

# %%
hotel.head()
# Out:
#                         Name                     Address   Price  \
# 0      The Silk Route Ladakh  Leh, 1.1 km to City centre  ₹3,357
# 1       The Nature Residency  Leh, 4.9 km to City centre  ₹3,880
# 2  Donskit Guesthouse Room 2  Leh, 2.1 km to City centre  ₹1,597
# 3         Gongma Guest House  Leh, 0.8 km to City centre  ₹1,368
# 4        Hotel Ladakh Heaven  Leh, 1.4 km to City centre  ₹4,308
#
#                 Type Reviews  \
# 0              Hotel     7.7
# 1              Hotel     7.9
# 2  House / Apartment      10
# 3  House / Apartment     9.6
# 4              Hotel     8.1
#
#                                          description  Stars
# 0                                              Hotel    NaN
# 1                                              Hotel    3.0
# 2  Just addedHouse / ApartmentSuperhostSuperhosts...    NaN
# 3  Just addedHouse / ApartmentEntire place16 gues...    3.0
# 4                                              Hotel    NaN

# %%
hotel.columns
# Out:
# Index(['Name', 'Address', 'Price', 'Type', 'Reviews', 'description', 'Stars'], dtype='object')

# %%
get_loc(hotel['Address'][4],'latitude')
# Out:
# {'results': [{'address_components': [{'long_name': 'Leh', 'short_name': 'Leh', 'types': ['locality', 'political']}], 'formatted_address': 'Leh', 'geometry': {'bounds': {'northeast': {'lat': 34.2130798, 'lng': 77.6152326}, 'southwest': {'lat': 34.1194435, 'lng': 77.5182438}}, 'location': {'lat': 34.1525864, 'lng': 77.57705349999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 34.2130798, 'lng': 77.6152326}, 'southwest': {'lat': 34.1194435, 'lng': 77.5182438}}}, 'partial_match': True, 'place_id': 'ChIJhe1fRCHr_TgREPeGUJcJu9E', 'types': ['locality', 'political']}], 'status': 'OK'}
# 34.1525864

# %%
import googlemaps
from datetime import datetime
def get_location(address):
    gmaps = googlemaps.Client(key='AIzaSyCSnuuGE7ZcSHPJUUXU6p2SJiyehAfWTQ8')
    geocode_result = gmaps.geocode(address)
    print(geocode_result)

# %%
print(geocode_result)
# Out:
# [{'address_components': [{'long_name': '1600', 'short_name': '1600', 'types': ['street_number']}, {'long_name': 'Amphitheatre Parkway', 'short_name': 'Amphitheatre Pkwy', 'types': ['route']}, {'long_name': 'Mountain View', 'short_name': 'Mountain View', 'types': ['locality', 'political']}, {'long_name': 'Santa Clara County', 'short_name': 'Santa Clara County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'California', 'short_name': 'CA', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}], 'formatted_address': '1600 Amphitheatre Pkwy, Mountain View, CA 94043, USA', 'geometry': {'location': {'lat': 37.4216129, 'lng': -122.0857393}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 37.4229618802915, 'lng': -122.0843903197085}, 'southwest': {'lat': 37.4202639197085, 'lng': -122.08708828029
# ...
